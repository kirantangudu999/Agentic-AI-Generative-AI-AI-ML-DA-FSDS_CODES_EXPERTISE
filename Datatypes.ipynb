# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
intvar = 10 # Integer variable
floatvar = 2.57 # Float Variable
strvar = "Python Language" # String variable
print(intvar)
print(floatvar) 
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1 = p2 = p3 = p4 = 44 # All variables pointing to same value
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %%
val1 = 10 # Integer data type
print(val1)
print(type(val1)) # type of object
print(sys.getsizeof(val1)) # size of integer object in bytes
print(val1, " is Integer?", isinstance(val1, int))
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2 = 92.78 # Float data type
print(val2)
print(type(val2)) # type of object
print(sys.getsizeof(val2)) # size of float object in bytes
print(val2, " is float?", isinstance(val2, float))
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78  is float? True

# %%
val3 = 25 + 10j # Complex data type
print(val3)
print(type(val3)) # type of object
print(sys.getsizeof(val3)) # size of float object in bytes
print(val3, " is complex?", isinstance(val3, complex)) # val3 is an instance of
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j)  is complex? True

# %%
sys.getsizeof(int())
# Out:
# 28

# %%
s=6565757657657657657879798798787978898888888888888888888888888888888888888888888888888888888888
s
# Out:
# 6565757657657657657879798798787978898888888888888888888888888888888888888888888888888888888888

# %%
bool1 = True

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
isinstance(bool1, bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
mystr = ('Happy '
'Monday ' 'Everyone')

# %%
print(mystr)
# Out:
# Happy Monday Everyone

# %%
str1 ='Hello my dear'
str1
# Out:
# 'Hello my dear'

# %%
len(str1)
# Out:
# 13

# %%
str1[len(str1)-1]
# Out:
# 'r'

# %%
str1[0:5]
# Out:
# 'Hello'

# %%
str1[-4:]
# Out:
# 'dear'

# %%
str1[:4]
# Out:
# 'Hell'

# %%
str1[:-4]
# Out:
# 'Hello my '

# %%
str1[:6]
# Out:
# 'Hello '

# %%
int(2.4)
# Out:
# 2

# %%
int(2.4, 3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 int(2.4, 3.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 int(2, 3)
#
# TypeError: int() can't convert non-string with explicit base

# %%
bool(10)
# Out:
# True

# %%
bool(1.5)
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
complex(False)
# Out:
# 0j

# %%
print(True*2)
# Out:
# 2

# %%
poll_data = 7,

# %%
obj_data = ( )

# %%
int(True)
# Out:
# 1

# %%
int("1")
# Out:
# 1

# %%
obj_data = ()

# %%
dict(range(9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dict(range(9))
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
set(range(9))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
list(range(9))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
tuple(range(9))
# Out:
# (0, 1, 2, 3, 4, 5, 6, 7, 8)
