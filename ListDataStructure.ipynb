# %%
m=[]

# %%
m.append(10)
m.append(30)

# %%
m
# Out:
# [10, 30]

# %%
m.append(m)

# %%
m
# Out:
# [10, 30, [...]]

# %%
len(m)
# Out:
# 3

# %%
m.remove(m)

# %%
m
# Out:
# [10, 30]

# %%
m.append(40)
m.append(50)
m.append(60)

# %%
m
# Out:
# [10, 30, 40, 50, 60]

# %%
m[:]
# Out:
# [10, 30, 40, 50, 60]

# %%
m[:-1]
# Out:
# [10, 30, 40, 50]

# %%
m[:-6]
# Out:
# []

# %%
m[:-8]
# Out:
# []

# %%
m[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 m[6]
#
# IndexError: list index out of range

# %%
m[-3]

# %%
m[::-1]

# %%
m[:]

# %%
m=m.copy()

# %%
m

# %%
m.extend(m)

# %%
m

# %%
m.count(40)

# %%
m.append(50)
m.append(60)
m.append(70)

# %%
m
# Out:
# [10, 30, 40, 50, 60, 50, 60, 70, 50, 60, 70]

# %%
40 in m
# Out:
# True

# %%
1000 in m
# Out:
# False

# %%
m.index(70)
# Out:
# 7

# %%
m[0:6]
# Out:
# [10, 30, 40, 50, 60, 50]

# %%
m[::-1]
# Out:
# [70, 60, 50, 70, 60, 50, 60, 50, 40, 30, 10]

# %%
m[::-3]
# Out:
# [70, 70, 60, 30]

# %%
m
# Out:
# [10, 30, 40, 50, 60, 50, 60, 70, 50, 60, 70]

# %%
m[::-3]
# Out:
# [70, 70, 60, 30]

# %%
m[2:9:2]
# Out:
# [40, 60, 60, 50]

# %%
m[2:9:2]
# Out:
# [40, 60, 60, 50]

# %%
print(m)
# Out:
# [10, 30, 40, 50, 60, 50, 60, 70, 50, 60, 70]

# %%
m.pop()
# Out:
# 70

# %%
m.pop(3)
# Out:
# 50

# %%
m
# Out:
# [10, 30, 40, 60, 50, 50, 60]

# %%
m.pop(-3)
# Out:
# 60

# %%
m
# Out:
# [10, 30, 40, 60, 50, 50, 60]

# %%
m.pop(-3)
# Out:
# 50

# %%
m
# Out:
# [10, 30, 40, 60, 50, 60]

# %%
m.pop(-2)
m
# Out:
# [10, 30, 40, 60, 60]

# %%
m.remove(40)

# %%
m
# Out:
# [10, 30, 60, 60]
