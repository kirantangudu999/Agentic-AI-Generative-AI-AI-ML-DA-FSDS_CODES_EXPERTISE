# %%
c = (50 - 5 * 6) / 4

# %%
print(c)
# Out:
# 5.0

# %%
17 // 3
# Out:
# 5

# %%
17 % 3
# Out:
# 2

# %%
5 * 3 + 2
# Out:
# 17

# %%
2 ** 7
# Out:
# 128

# %%
4 * 3.75 - 1
# Out:
# 14.0

# %%
_
# Out:
# '{"dataframes": [], "user": "kiran"}'

# %%
tax = 12.5/100
price = 100
price * tax
# Out:
# 12.5

# %%
10 + 5
# Out:
# 15

# %%
 _
# Out:
# '{"dataframes": [], "user": "kiran"}'

# %%
print(_)
# Out:
# {"dataframes": [], "user": "kiran"}

# %%
tax = 12.5/100

# %%
price = 100.5

# %%
price * tax
# Out:
# 12.5

# %%
5  + 3
# Out:
# 8

# %%
print(_)
# Out:
# {"dataframes": [], "user": "kiran"}

# %%
import sys
sys.version
# Out:
# '3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]'

# %%
print(_)
# Out:
# {"dataframes": [], "user": "kiran"}

# %%
print(_)
# Out:
# {"dataframes": [], "user": "kiran"}

# %%
5 + 3
# Out:
# 8

# %%
print(_)
# Out:
# {"dataframes": [], "user": "kiran"}

# %%
'spam eggs'
# Out:
# 'spam eggs'

# %%
"samp eggs"
# Out:
# 'samp eggs'

# %%
''' testing '''
# Out:
# ' testing '

# %%
''' testing 
            python'''
# Out:
# ' testing \n            python'

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
"doesn\'t"
# Out:
# "doesn't"

# %%
"\"yes,\" they said."
# Out:
# '"yes," they said.'

# %%
"\"yes, they said."
# Out:
# '"yes, they said.'

# %%
"\"yes,\" they said.\""
# Out:
# '"yes," they said."'

# %%
"\"yes, they said.\""
# Out:
# '"yes, they said."'

# %%
S = 'Fist line \n second line '

# %%
print(S)
# Out:
# Fist line
#  second line

# %%
print(""" asdfasf
      sdfsd
      dfgdfgd
      """)
# Out:
#  asdfasf
#       sdfsd
#       dfgdfgd

# %%
long_string = "This is a very long string that " \
                  "needs to be broken into multiple " \
                  "lines for readability."

# %%
print(long_string)
# Out:
# This is a very long string that needs to be broken into multiple lines for readability.

# %%
another_multiline_string = ("This string is also "
                                "spanning multiple lines "
                                "using parentheses.")

# %%
print(another_multiline_string)
# Out:
# This string is also spanning multiple lines using parentheses.

# %%
'py' 'tho'
# Out:
# 'pytho'

# %%
3 * 'sd'
# Out:
# 'sdsdsd'

# %%
word = 'python'

# %%
word[0]
# Out:
# 'p'

# %%
word[0:2]
# Out:
# 'py'

# %%
word[0:]
# Out:
# 'python'

# %%
'spam eggs'
# Out:
# 'spam eggs'

# %%
"Is n't it"
# Out:
# "Is n't it"

# %%
"\"yes,\" they said."
# Out:
# '"yes," they said.'

# %%
"Is \n't it"
# Out:
# "Is \n't it"

# %%
print("Is \n't it")
# Out:
# Is
# 't it

# %%
print(r'C:\some\name')
# Out:
# C:\some\name

# %%
text = ('afdasdf '
        'asdfasdf')

# %%
text
# Out:
# 'afdasdf asdfasdf'

# %%
word = 'python'

# %%
word[-0]
# Out:
# 'p'

# %%
word[0:5]
# Out:
# 'pytho'

# %%
word[-1:]
# Out:
# 'n'

# %%
word[2:]
# Out:
# 'thon'

# %%
word[:2]
# Out:
# 'py'

# %%
squares = [1,2,3,4,5,6]

# %%
squares[0]
# Out:
# 1

# %%
squares[-1]
# Out:
# 6

# %%
squares[-3:]
# Out:
# [4, 5, 6]

# %%
squares.append(7)

# %%
squares
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
squares[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7]
