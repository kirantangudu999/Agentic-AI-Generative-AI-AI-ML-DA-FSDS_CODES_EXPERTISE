# %% [markdown]
# # 1st code -- work with number

# %%
2
# Out:
# 2

# %%
3
# Out:
# 3

# %%
2 + 3
# Out:
# 5

# %%
3 +
# Out:
#   Cell In[4], line 1
#     3 +
#         ^
# SyntaxError: invalid syntax

# %%
3 + 5
# Out:
# 8

# %%
_ + 2
# Out:
# 10

# %%
_ + 5
# Out:
# 15

# %%
_ + 4
# Out:
# 19

# %%
3 + 3 * 5 - 2
# Out:
# 16

# %%
(3 + 3) * 5 - 2
# Out:
# 28

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5 # float division
# Out:
# 2.0

# %%
10 // 5 # integer division
# Out:
# 2

# %%
10 % 5  # reminder
# Out:
# 0

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2
# Out:
# 9

# %%
3 *** 2
# Out:
#   Cell In[19], line 1
#     3 *** 2
#         ^
# SyntaxError: invalid syntax

# %%
10 + 2
10 - 2
# Out:
# 8

# %%
print(10+2)
print(10-2)
# Out:
# 12
# 8
